# %%
import pandas as pd
import tweepy
import random

# %%
# Configuración de la API de Twitter (asegúrate de tener tus propias claves)
api_key = "t1TmTGZfCfebvaseP7Wz4yUP3"
api_secret_key = "KNZ6KfPRvGzQsEQ5JF4JRF91orVCx8rasCbTBlQjhPYDBIaxBl"
access_token = "1780377244126380033-PVgOC5wmEHsm0r3qrHAk7bpFbRpnoP"
access_token_secret = "6b0YYT6Vq5AZKjTumZvqaxOeGI8r4uRmw14D72Y5FbFk4"
bearer_token = "AAAAAAAAAAAAAAAAAAAAAHX5ugEAAAAAO%2B6Tbx1WdlxdeOjz3rPiE%2BuZTaQ%3DibH5C0VfuLxMs8mGfULfzVR6SsRZH0zHeVEunNnHkGYnE9F1H3"

# %%
# Autenticación con la API de Twitter
client = tweepy.Client(bearer_token=bearer_token, wait_on_rate_limit=True)

# %%
# Léxico de palabras clave refinado y ampliado
lexicon_optimizado = [
    "asilo", "refugio", "inmigrante", "deportación", "residencia", "permiso",
    "miedo", "esperanza", "tristeza", "alegría", "frustración", "alivio", "ansiedad", "gratitud",
    "cruce", "frontera", "travesía", "ruta", "caravana", "coyotes", "rutas peligrosas",
    "violencia", "detención", "extorsión", "discriminación", "inseguridad", "peligro",
    "familia", "hijos", "separación", "comunidad", "apoyo", "solidaridad",
    "albergue", "comida", "salud", "educación", "trabajo", "ayuda", "recursos",
    "México", "Estados Unidos", "Guatemala", "Tijuana", "Tapachula", "frontera norte", "frontera sur",
    "buscando una vida mejor", "huyendo de la violencia", "cruzar la frontera", "en busca de asilo"
]

# %%
# Seleccionar 15 palabras clave aleatorias del léxico
selected_keywords = random.sample(lexicon_optimizado, 15)

# Función para buscar tweets usando el léxico
def search_tweets(keywords):
    tweets_data = []
    for word in keywords:
        query = f"{word} lang:es -is:retweet"
        try:
            for tweet in tweepy.Paginator(client.search_recent_tweets, query=query, tweet_fields=['created_at', 'text', 'author_id'], max_results=10).flatten(limit=10):
                tweets_data.append({
                    'keyword': word,
                    'created_at': tweet.created_at,
                    'user_id': tweet.author_id,
                    'text': tweet.text
                })
            print(f"Extracted tweets for keyword: {word}")
        except tweepy.TweepyException as e:
            print(f"Error: {e}")
    return tweets_data

# %%
# Buscar tweets
tweets_data = search_tweets(selected_keywords)

# Convertir los datos a un DataFrame de pandas
df_tweets = pd.DataFrame(tweets_data)

# Guardar los tweets en un archivo CSV
df_tweets.to_csv('tweets_migracion.csv', index=False, encoding='utf-8-sig')

# Mostrar algunos ejemplos de tweets encontrados
print(df_tweets.head(10))
# Out:
# Extracted tweets for keyword: extorsión
# Extracted tweets for keyword: residencia
# Extracted tweets for keyword: solidaridad
# Extracted tweets for keyword: frontera norte
# Extracted tweets for keyword: rutas peligrosas
# Extracted tweets for keyword: apoyo
# Extracted tweets for keyword: recursos
# Extracted tweets for keyword: travesía
# Extracted tweets for keyword: hijos
# Extracted tweets for keyword: alivio
# Extracted tweets for keyword: gratitud
# Extracted tweets for keyword: salud
# Extracted tweets for keyword: caravana
# Extracted tweets for keyword: Tapachula
# Extracted tweets for keyword: deportación
#      keyword                created_at              user_id  \
# 0  extorsión 2024-07-09 05:43:51+00:00             85943268
# 1  extorsión 2024-07-09 05:34:21+00:00  1701343598220840960
# 2  extorsión 2024-07-09 05:33:49+00:00  1655958977354817537
# 3  extorsión 2024-07-09 05:25:16+00:00  1544440834938077185
# 4  extorsión 2024-07-09 05:24:47+00:00  1585397205376139273
# 5  extorsión 2024-07-09 05:22:37+00:00            304982169
# 6  extorsión 2024-07-09 05:19:14+00:00  1549747229778329601
# 7  extorsión 2024-07-09 05:14:38+00:00  1445064423912181761
# 8  extorsión 2024-07-09 05:13:26+00:00  1092303854924787713
# 9  extorsión 2024-07-09 05:12:15+00:00  1390820345339318273
#
#                                                 text
# 0  @delfinagomeza Y eso qué..! No se ha bajado la...
# 1  @Notisistema Ellos se reportan a los altos man...
# 2  El chantaje crece sin contención https://t.co/...
# 3  @madorni Aplaudo la extorsión.   Se ve que sur...
# 4  No mames seguro ese es el menor de su delitos,...
# 5  @elgatopolitico_ Jajaja seguro que si jajaja d...
# 6  @juncalssolano @Martin_Bazan_A Bueno, si este ...
# 7  @jparedescordova El vejestorio es nostálgico d...
# 8  Al final él se lo dió a ella y las personas qu...
# 9  Asesinan de más de 20 tiros a presidenta de Cá...

# %%
display(df_tweets)
# Out:
#        keyword                created_at              user_id  \
# 0    extorsión 2024-07-09 05:43:51+00:00             85943268
# 1    extorsión 2024-07-09 05:34:21+00:00  1701343598220840960
# 2    extorsión 2024-07-09 05:33:49+00:00  1655958977354817537
# 3    extorsión 2024-07-09 05:25:16+00:00  1544440834938077185
# 4    extorsión 2024-07-09 05:24:47+00:00  1585397205376139273
# 5    extorsión 2024-07-09 05:22:37+00:00            304982169
# 6    extorsión 2024-07-09 05:19:14+00:00  1549747229778329601
# 7    extorsión 2024-07-09 05:14:38+00:00  1445064423912181761
# 8    extorsión 2024-07-09 05:13:26+00:00  1092303854924787713
# 9    extorsión 2024-07-09 05:12:15+00:00  1390820345339318273
# 10  residencia 2024-07-09 05:45:00+00:00  1039780670120361984
# 11  residencia 2024-07-09 05:44:56+00:00           3063851409
# 12  residencia 2024-07-09 05:44:48+00:00            196164638
# 13  residencia 2024-07-09 05:41:28+00:00            195586192
# 14  residencia 2024-07-09 05:41:07+00:00  1776790689952788480
#
#                                                  text
# 0   @delfinagomeza Y eso qué..! No se ha bajado la...
# 1   @Notisistema Ellos se reportan a los altos man...
# 2   El chantaje crece sin contención https://t.co/...
# 3   @madorni Aplaudo la extorsión.   Se ve que sur...
# 4   No mames seguro ese es el menor de su delitos,...
# 5   @elgatopolitico_ Jajaja seguro que si jajaja d...
# 6   @juncalssolano @Martin_Bazan_A Bueno, si este ...
# 7   @jparedescordova El vejestorio es nostálgico d...
# 8   Al final él se lo dió a ella y las personas qu...
# 9   Asesinan de más de 20 tiros a presidenta de Cá...
# 10  El cambio de la fábrica de Marie Claire en Cas...
# 11  Cuántas trabajadoras debe haber en una residen...
# 12  ❌ ACTIVIDADES CONTRADICTORIAS EN INCAPACIDAD T...
# 13  @tarekawilianaSa Es una residencia presidencia...
# 14  @lopezobrador_ La causa pública, con residenci...
